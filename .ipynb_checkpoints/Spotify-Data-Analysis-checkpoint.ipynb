# %% [markdown]
# # <u>Spotify Top Track Analysis</u>
# ## Ben Johanski
# <hr>

# %% [markdown]
# # <u>Summary</u>
#  - Dataset Source: https://www.kaggle.com/datasets/josephinelsy/spotify-top-hit-playlist-2010-2022
#
# ## Sections
#  - [Goals](#goals)
#  - [Data Loading and Libraries](#DLL)
#  - [Summary Statistics](#summary_stats)
#  - [Data Cleaning and Tidying](#data_cleaning)
#  - [Basic Visualizations](#basic_visualizations)
#  - [EDA](#EDA)
#  - [Conclusions and Findings](#conclusion)
# ## Project Goals <a class='anchor' id='Goals'></a>
#  - The purpose of the following analysis is to identify trends and connections between popular tracks from the spotify top hits playlist. As a musician, I'm excited to see if there are any trends through time and between variables. Maybe this will give me some insight into characteristics which I should include in my next track! Some of the topics which I intend to explore are as follows:
#      - If I were to want to publish a track with the intent of it gaining popularity, I would like to know if there are any audio features (danceability, key, energy, etc.) that appears more in this sample of tracks.
#      - Are there any trends through time as it pertains to top tracks and audio features? Track length?

# %% [markdown]
# ## Data Loading and Libraries <a class='anchor' id='DLL'></a>

# %%
#Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
#Importing Spotify data
spotify_data = pd.read_csv('playlist_2010to2022.csv')

# %% [markdown]
# ## Summary Statistics <a class='anchor' id='summary_stats'></a>

# %%
#Creating a list of columns for ease of access.
spotify_columns = list(spotify_data.columns)
print(spotify_columns)

#Checking layout of data
spotify_data.head(10)
# Out:
# ['playlist_url', 'year', 'track_id', 'track_name', 'track_popularity', 'album', 'artist_id', 'artist_name', 'artist_genres', 'artist_popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']
#                                         playlist_url  year  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 5  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 6  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 7  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 8  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 9  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
#
#                  track_id            track_name  track_popularity  \
# 0  3AJwUDP919kvQ9QcozQPxg                Yellow                91
# 1  2m1hi0nfMR9vdGC8UcrnwU  All The Small Things                84
# 2  3y4LxiYMgDl4RethdzpmNe               Breathe                69
# 3  60a0Rd6pjrkxjPbaKzXjfq            In the End                88
# 4  62bOmKYxYg7dhrC6gH9vFn           Bye Bye Bye                74
# 5  5Mmk2ii6laakqfeCT7OnVD            Thong Song                73
# 6  3yfqSUWxFvZELEM4PmlwIR   The Real Slim Shady                88
# 7  7oQSevUCbYs4QawXTHQVV1               Rock DJ                57
# 8  7H6ev70Weq6DdpZyyTmUXk           Say My Name                80
# 9  64BbK9SFKH2jk86U3dGj2P             Otherside                83
#
#                               album               artist_id  \
# 0                        Parachutes  4gzpq5DPGxSnKTe4SA8HAU
# 1                Enema Of The State  6FBDaR13swtiWwGhX1WQsP
# 2                           Breathe  25NQNriVT2YbSW80ILRWJa
# 3     Hybrid Theory (Bonus Edition)  6XyY86QOPPrYVGvF9ch6wz
# 4               No Strings Attached  6Ff53KvcvAj5U7Z1vojB5o
# 5                Unleash The Dragon  6x9QLdzo6eBZxJ1bHsDkjg
# 6           The Marshall Mathers LP  7dGJo4pcD2V6oG8kP0tJRR
# 7          Sing When You're Winning  2HcwFjNelS49kFbfvMxQYw
# 8         The Writing's On The Wall  1Y8cdNmUJH7yBTd9yOvr5i
# 9  Californication (Deluxe Edition)  0L8ExT028jH3ddEcZwqJJ5
#
#              artist_name                                      artist_genres  \
# 0               Coldplay                          ['permanent wave', 'pop']
# 1              blink-182  ['alternative metal', 'modern rock', 'pop punk...
# 2             Faith Hill  ['contemporary country', 'country', 'country d...
# 3            Linkin Park  ['alternative metal', 'nu metal', 'post-grunge...
# 4                 *NSYNC                   ['boy band', 'dance pop', 'pop']
# 5                  Sisqo  ['contemporary r&b', 'dirty south rap', 'hip p...
# 6                 Eminem              ['detroit hip hop', 'hip hop', 'rap']
# 7        Robbie Williams                          ['dance rock', 'europop']
# 8        Destiny's Child  ['dance pop', 'girl group', 'pop', 'r&b', 'urb...
# 9  Red Hot Chili Peppers  ['alternative rock', 'funk metal', 'funk rock'...
#
#    artist_popularity  ...  loudness  mode  speechiness  acousticness  \
# 0                 86  ...    -7.227   1.0       0.0281       0.00239
# 1                 75  ...    -4.918   1.0       0.0488       0.01030
# 2                 61  ...    -9.007   1.0       0.0290       0.17300
# 3                 83  ...    -5.870   0.0       0.0584       0.00958
# 4                 65  ...    -4.843   0.0       0.0479       0.03100
# 5                 56  ...    -6.959   1.0       0.0654       0.11900
# 6                 88  ...    -4.244   0.0       0.0572       0.03020
# 7                 69  ...    -4.307   1.0       0.0326       0.02600
# 8                 69  ...    -3.525   0.0       0.1020       0.27300
# 9                 80  ...    -3.265   1.0       0.0574       0.00316
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000121    0.2340    0.285  173.372     266773.0             4.0
# 1          0.000000    0.6120    0.684  148.726     167067.0             4.0
# 2          0.000000    0.2510    0.278  136.859     250547.0             4.0
# 3          0.000000    0.2090    0.400  105.143     216880.0             4.0
# 4          0.001200    0.0821    0.861  172.638     200400.0             4.0
# 5          0.000096    0.0700    0.714  121.549     253733.0             4.0
# 6          0.000000    0.0454    0.760  104.504     284200.0             4.0
# 7          0.000000    0.0981    0.842  103.032     260560.0             4.0
# 8          0.000000    0.1490    0.734  138.009     271333.0             4.0
# 9          0.000202    0.0756    0.513  123.229     255373.0             4.0
#
# [10 rows x 23 columns]

# %%
#Checking value data types
spotify_data.dtypes
# Out:
# playlist_url          object
# year                   int64
# track_id              object
# track_name            object
# track_popularity       int64
# album                 object
# artist_id             object
# artist_name           object
# artist_genres         object
# artist_popularity      int64
# danceability         float64
# energy               float64
# key                  float64
# loudness             float64
# mode                 float64
# speechiness          float64
# acousticness         float64
# instrumentalness     float64
# liveness             float64
# valence              float64
# tempo                float64
# duration_ms          float64
# time_signature       float64
# dtype: object

# %%
#Summary statistics
spotify_data.describe()
# Out:
#               year  track_popularity  artist_popularity  danceability  \
# count  2300.000000       2300.000000        2300.000000   2299.000000
# mean   2011.000000         70.943478          72.869565      0.660116
# std       6.634692         12.291526          12.179263      0.141137
# min    2000.000000          0.000000          29.000000      0.162000
# 25%    2005.000000         66.000000          65.000000      0.572000
# 50%    2011.000000         72.000000          74.000000      0.671000
# 75%    2017.000000         79.000000          82.000000      0.759500
# max    2022.000000        100.000000         100.000000      0.975000
#
#             energy          key     loudness         mode  speechiness  \
# count  2299.000000  2299.000000  2299.000000  2299.000000  2299.000000
# mean      0.693047     5.277947    -5.784040     0.598521     0.097795
# std       0.164838     3.628494     2.080853     0.490304     0.092445
# min       0.051900     0.000000   -21.107000     0.000000     0.022500
# 25%       0.586000     2.000000    -6.823500     0.000000     0.038000
# 50%       0.712000     5.000000    -5.511000     1.000000     0.056800
# 75%       0.820000     8.000000    -4.364500     1.000000     0.115500
# max       0.999000    11.000000    -0.276000     1.000000     0.576000
#
#        acousticness  instrumentalness     liveness      valence        tempo  \
# count   2299.000000       2299.000000  2299.000000  2299.000000  2299.000000
# mean       0.157689          0.013766     0.172618     0.535110   120.512450
# std        0.203844          0.083990     0.131620     0.227821    27.617729
# min        0.000013          0.000000     0.021000     0.037700    60.019000
# 25%        0.016500          0.000000     0.089950     0.360500    98.569500
# 50%        0.068900          0.000000     0.119000     0.540000   120.000000
# 75%        0.223000          0.000054     0.220000     0.722000   137.028000
# max        0.978000          0.985000     0.843000     0.974000   210.857000
#
#          duration_ms  time_signature
# count    2299.000000     2299.000000
# mean   226033.494128        3.982166
# std     42063.678588        0.219054
# min     97393.000000        1.000000
# 25%    200179.500000        4.000000
# 50%    221653.000000        4.000000
# 75%    245950.000000        4.000000
# max    688453.000000        5.000000

# %% [markdown]
# ## Data Cleaning and Tidying <a class='anchor' id='data_cleaning'></a>

# %%
#Checking to see if any duplicates are found after initial review. Using a formula to quickly run through each column

#Column check
for i in range(len(spotify_columns)):
    col_name = spotify_columns[i]
    current_col = spotify_data[col_name]
    dupe_count = 0
    for i in current_col:
        if i == True:
            dupe_count += 1
    print("Potential Dupes for {}: ".format(col_name) + str(dupe_count))
# Out:
# 0
# Potential Dupes for playlist_url: 0
# Potential Dupes for year: 0
# Potential Dupes for track_id: 0
# Potential Dupes for track_name: 0
# Potential Dupes for track_popularity: 3
# Potential Dupes for album: 0
# Potential Dupes for artist_id: 0
# Potential Dupes for artist_name: 0
# Potential Dupes for artist_genres: 0
# Potential Dupes for artist_popularity: 0
# Potential Dupes for danceability: 0
# Potential Dupes for energy: 0
# Potential Dupes for key: 297
# Potential Dupes for loudness: 0
# Potential Dupes for mode: 1376
# Potential Dupes for speechiness: 0
# Potential Dupes for acousticness: 0
# Potential Dupes for instrumentalness: 0
# Potential Dupes for liveness: 0
# Potential Dupes for valence: 0
# Potential Dupes for tempo: 0
# Potential Dupes for duration_ms: 0
# Potential Dupes for time_signature: 4

# %%
# Checking for null values
total_null_count = spotify_data.isnull().sum().sum()
print('Total number of null values:', total_null_count)

# Number of nulls by columns
column_null_count = spotify_data.isnull().sum()
print(column_null_count)

# Quickly identifying if this is just a single song which can be removed
null_tempo_row = spotify_data[spotify_data['tempo'].isnull()]
null_tempo_row

# Above I confirmed that the NA values belong to one entry. For this reason, I will be dropping that entry.
spotify_data = spotify_data.drop(447)

# Confirming that the row is gone.
spotify_data.iloc[[447]]
# Out:
# Total number of null values: 0
# playlist_url         0
# year                 0
# track_id             0
# track_name           0
# track_popularity     0
# album                0
# artist_id            0
# artist_name          0
# artist_genres        0
# artist_popularity    0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# duration_ms          0
# time_signature       0
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 14
#      11 null_tempo_row
#      13 # Above I confirmed that the NA values belong to one entry. For that reason, I will be dropping that entry.
# ---> 14 spotify_data = spotify_data.drop(447)
#      16 # Confirming that the row is gone.
#      17 spotify_data.iloc[[447]]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: '[447] not found in axis'

# %% [markdown]
# ## Basic Visualizations<a class='anchor' id='basic_visualizations'></a>
#  - By visualizing some of our summary statistics, I would like to identify if we have any outliers that might require additional attention, and see if any variables raise any additional questions to investigate.

# %%
#Before creating some visualizations, I want to see if any outliers are in our dataset.

#Beginning by identifying variables for plotting
vars_boxplots = ['year','track_popularity','danceability','energy','loudness',\
                 'speechiness','acousticness', 'instrumentalness','liveness','valence','duration_ms']

#Writing a (somewhat) reuseable function for plotting multiple charts.
def outlier_boxplot_check(df, columns):
    for i in range(len(vars_boxplots)):
        current_col = df[columns[i]]
        plt.figure(figsize=(2,3))
        plt.boxplot(current_col)
        plt.title('{}'.format(columns[i]).title())
        plt.tight_layout()
        plt.show()
        plt.clf()

outlier_boxplot_check(spotify_data, vars_boxplots)

# It looks like some of the characteristic values for tracks have multiple outliers either above or below the IQR.
# Once I begin EDA, I will remove outliers and focus mainly on the IQR of each variable.

# %% [markdown]
# ## EDA  <a class='anchor' id='EDA'></a>

# %%
# Creating histograms for each variable

# Begin with listing out variables to plot in hist model
vars_for_hists = ['year','track_popularity','danceability','energy','key','loudness',\
                 'speechiness','acousticness', 'instrumentalness','liveness','valence','tempo','duration_ms']

#Creating function for creating a historgram for each variable identified
def hist_builder(df, columns):
    # Random colors for hists, because they're pretty
    r = lambda: random.randint(0,255)
    
    # Looping through to create a hist for each desired variable
    for i in range(len(vars_boxplots)):
        random_color = ('#%02X%02X%02X' % (r(),r(),r()))
        current_col = df[columns[i]]
        plt.figure(figsize=(5,3))
        ax = plt.subplot()
        ax.grid(True, alpha=0.25)
        plt.ylabel('Count')
        plt.xlabel(vars_for_hists[i].title())
        plt.hist(current_col, alpha = 0.75, color=random_color, edgecolor='black')
        plt.title('{}'.format(columns[i]).title())
        plt.tight_layout()
        plt.show()
        plt.clf()
        
hist_builder(spotify_data, vars_for_hists)

# %% [markdown]
# ### Hist Review
# Notes:
#  - The mode for danceability appears to land around 0.6-0.7. It is a unimodal hist.
#  - Song energy, danceability, and loudness all are left skewed and unimodal. This points to our sample being comprised of tracks which are typically louder, dancier, and  more energetic.
#  - Key, as expected, appears to be more random. However, as a musician, it is intriguing to see the majority of songs are equal to one. No documentation which I found indicated the order of keys, but my assumption that 1 = C Major, while 12 = B Major.
#  - Valence (happy vs. sad emotion) appears to have a normalized distribution.

# %%
# Below I would like to focus on the main track characteristics provided by the data set versus track popularity.

# Isolating song variables into a separate list
song_variables = ['loudness','speechiness','acousticness','danceability','energy','key','instrumentalness','liveness','valence','tempo','duration_ms']
len(song_variables)

# Creating a separate function to produce multiple scatter plots
def scatter_plot_spotify_vars():
    plt.figure(figsize=(12,8))

    for i in range(len(song_variables)):
        
        # Selecting each subplot to use
        ax = plt.subplot(3, 4, i + 1)
        
        # Random colors for scatter plots, because they're pretty
        r = lambda: random.randint(0,255)
        random_color = ('#%02X%02X%02X' % (r(),r(),r()))
        
        # Isolating single column for plotting
        current_variable = spotify_data[song_variables[i]]
        track_pop = spotify_data['track_popularity']
        
        # Plotting and labeling
        plt.scatter(track_pop, current_variable, alpha=0.15, color = random_color)
        plt.tight_layout()
        plt.ylabel('Track {}'.format(song_variables[i]).title())
        plt.xlabel('Track Popularity')
        plt.title('Track Popularity vs. {}'.format(song_variables[i]).title())
        plt.tight_layout()
        
        ax.grid(True, alpha=0.5)

scatter_plot_spotify_vars()

# %%
# Reviewing correlation of variables with a heat map.

# Separate out all numeric data types into correlation matrix
corr_matrix = spotify_data.select_dtypes(include=['int64','float64']).corr(method='pearson')

# Color Palette 
palette = sns.diverging_palette(220, 20, as_cmap=True)

# Creating heat map of correlation between each variable
fig, axs = plt.subplots(1,1, figsize=(10,10))
sns.heatmap(corr_matrix, annot=True, cmap=palette, fmt='0.2f')
plt.tight_layout()
plt.title('Correlation of Quantitative Variables')
plt.show()
plt.clf()

# %% [markdown]
# ### Heat Map Notes
#  - The strongest positive correlation between variables belongs to loudness and energy, while the strongest negative correlation between variables belongs to acousticness and energy.
#  - Notable correlations also include valence and energy, valence and key, artist popularity and year, and duration_ms and year.

# %% [markdown]
# # Mean Track Characteristics by Year

# %%
# Below I am going to separate and analyze track characteristics through time.

numerical_cats = spotify_data.select_dtypes(include=['int64','float64'])

track_characteristics = ['speechiness','acousticness','danceability','energy',\
                   'instrumentalness','liveness','valence']

years = numerical_cats.year.unique()

# Looping through the list of variables for plotting
for i in range(len(track_variables)):
        
    # Identifying Q1 and Q3 
    q1 = np.quantile(numerical_cats[track_characteristics[i]], 0.25) * 1.5
    q3 = np.quantile(numerical_cats[track_characteristics[i]], 0.75) * 1.5
        
    # Constraining dataset for each variable within IQR
    iqr_current_var = numerical_cats
    [((numerical_cats[track_characteristics[i]] >= q1) | (numerical_cats[track_characteristics[i]] <= q3))]
        
    # Separating mean values by year
    mean_by_year = iqr_current_var.groupby('year')[track_characteristics[i]].mean()
    
    # Plotting and formating
    plt.figure(figsize=(7.5,3))
    plt.plot(mean_by_year, color='blue', marker='o', linewidth=3, linestyle='--')
    plt.ylim(0, 1)
    plt.grid(True, alpha=0.5)
    plt.xticks(years, rotation=90)
    plt.xlim(2000, 2022)
    plt.tight_layout()
    plt.title('Avg. {} By Year'.format(track_variables[i]).title())
    plt.show()

# %%
# Analysis of average song length over time

# Identifying song length IQR
q1_length = np.quantile(spotify_data['duration_ms'], 0.25) * 1.5
q3_length = np.quantile(spotify_data['duration_ms'], 0.75) * 1.5
        
# Constraining dataset within IQR
iqr_current_var = numerical_cats
[((spotify_data['duration_ms'] >= q1) | (spotify_data['duration_ms'] <= q3))]
        
# Identifying mean values by year
mean_by_year = iqr_current_var.groupby('year')['duration_ms'].mean()

plt.figure(figsize=(7.5,3))
plt.plot(mean_by_year, color='lightblue', marker='o', linewidth=3, linestyle='--')
plt.grid(True, alpha=0.5)
plt.xticks(years, rotation=90)
plt.ylabel('Song Length (ms)')
plt.tight_layout()
plt.title('Avg Song Length by Year')
plt.show()

# %%
# Analysis of song tempo

# Identifying song tempo IQR
q1_length = np.quantile(spotify_data['tempo'], 0.25) * 1.5
q3_length = np.quantile(spotify_data['tempo'], 0.75) * 1.5
        
# Constraining dataset within IQR
iqr_current_var = numerical_cats
[((spotify_data['tempo'] >= q1) | (spotify_data['tempo'] <= q3))]
        
# Identifying mean value by year
mean_by_year = iqr_current_var.groupby('year')['tempo'].mean()

plt.figure(figsize=(7.5,3.5))
plt.plot(mean_by_year, color='lightblue', marker='o', linewidth=3, linestyle='--')
plt.grid(True, alpha=0.5)
plt.xticks(years, rotation=90)
plt.ylabel('Avg. Song Tempo (BPM)')
plt.tight_layout()
plt.title('Avg. Song Tempo by Year')
plt.show()

mean_length_2000 = iqr_current_var[iqr_current_var.year == 2000].duration_ms.mean()
mean_length_2022 = iqr_current_var[iqr_current_var.year == 2022].duration_ms.mean()

song_length_delta = abs(mean_length_2022-mean_length_2000)
print('Total mean change in song duration over time: ' + str(song_length_delta) + ' ms')
# Out:
# Total mean change in song duration over time: 50361.75 ms

# %%
# Analysis of song loudness

# Identifying song loudness IQR
q1_length = np.quantile(spotify_data['loudness'], 0.25) * 1.5
q3_length = np.quantile(spotify_data['loudness'], 0.75) * 1.5
        
# Constraining dataset within IQR
iqr_current_var = numerical_cats
[((spotify_data['loudness'] >= q1) | (spotify_data['loudness'] <= q3))]
        
# Identifying mean value by year
mean_by_year = iqr_current_var.groupby('year')['loudness'].mean()

plt.figure(figsize=(7.5,3.5))
plt.plot(mean_by_year, color='lightblue', marker='o', linewidth=3, linestyle='--')
plt.grid(True, alpha=0.5)
plt.xticks(years, rotation=90)
plt.ylabel('Avg. Song Loudness')
plt.tight_layout()
plt.title('Avg. Song Loudness by Year')
plt.show()

# %% [markdown]
# ## Conclusions and Findings <a class='anchor' id='conclusion'></a>

# %% [markdown]
#  - This analysis has shown that numerous track characteristics for popular songs from Spotify's Top 100 Hits playlist show signs of correlation and significance. A high level of danceability, loudness, and energy all appear to play an important role in a track gaining popularity. Low scores for acousticness, liveness, and speechiness are seen for tracks in the dataset, as well.
#  - In terms of time series analysis, the most significant change in top tracks appears to be duration. This dataset presents a decrease of 50361.75 ms, or about 50 seconds in average popular song length between 2000 and 2022.
#  - These insights would be very helpful for both professional musicians and those in the music industry, as it sets a precendent for what guidelines to follow when formulating a track.
#
#  - This dataset also has plenty of information which has not been analyzed just yet. Future analysis may consider:
#      - album
#      - album popularity
#      - artist popularity
#      - artist genres
